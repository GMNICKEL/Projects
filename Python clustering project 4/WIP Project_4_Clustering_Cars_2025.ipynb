# %% [markdown]
# Cars 2025 Dataset: https://www.kaggle.com/datasets/abdulmalik1518/cars-datasets-2025/dataLinks to an external site.
#
# I plan to group cars into different clusters following natural market segments. So far, I'm thinking “budget,” “family,” “sporty,” and “supercar,” depending on the specs of the vehicle. This should further help people decide on what car they want.
#
# On top of helping narrow down someone's vehicle choice, another impact might be that some potentially good vehicles could be missed if you only look at one cluster. For example, if someone wants a budget friendly family car, they may not find the best deal if they only look at the "family" cluster.

# %%
# All imports and directory for csv.
import numpy as np
import pandas as pd
import re
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

from google.colab import drive
drive.mount('/content/drive')
cars_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Cars Datasets 2025.csv", encoding="cp1252")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Clean dataset
num = lambda s: (
    (lambda txt: (
        np.nan if not re.findall(r'[\d.,]*\d(?:\.\d+)?', txt)
        else float(re.findall(r'[\d.,]*\d(?:\.\d+)?', txt)[0].replace(',', ''))
             * (1_000_000 if 'million' in txt else (1_000 if re.search(r'\bk\b', txt) else 1))
    ))(str(s).lower())
)
